# %% [markdown]
# # Preprocessing

# %%
#!pip install xgboost

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import StandardScaler
from xgboost import XGBClassifier
from xgboost import plot_importance
from matplotlib import pyplot
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from collections import Counter

# %%
# Get dataset
data = pd.read_csv('data/2015.csv')

# %%
data.head()
# Out:
#    _STATE  FMONTH        IDATE IMONTH   IDAY    IYEAR  DISPCODE         SEQNO  \
# 0     1.0     1.0  b'01292015'  b'01'  b'29'  b'2015'    1200.0  2.015000e+09
# 1     1.0     1.0  b'01202015'  b'01'  b'20'  b'2015'    1100.0  2.015000e+09
# 2     1.0     1.0  b'02012015'  b'02'  b'01'  b'2015'    1200.0  2.015000e+09
# 3     1.0     1.0  b'01142015'  b'01'  b'14'  b'2015'    1100.0  2.015000e+09
# 4     1.0     1.0  b'01142015'  b'01'  b'14'  b'2015'    1100.0  2.015000e+09
#
#            _PSU  CTELENUM  ...  _PAREC1  _PASTAE1  _LMTACT1  _LMTWRK1  \
# 0  2.015000e+09       1.0  ...      4.0       2.0       1.0       1.0
# 1  2.015000e+09       1.0  ...      2.0       2.0       3.0       3.0
# 2  2.015000e+09       1.0  ...      9.0       9.0       9.0       9.0
# 3  2.015000e+09       1.0  ...      4.0       2.0       1.0       1.0
# 4  2.015000e+09       1.0  ...      4.0       2.0       1.0       1.0
#
#    _LMTSCL1  _RFSEAT2  _RFSEAT3  _FLSHOT6  _PNEUMO2  _AIDTST3
# 0       1.0       1.0       1.0       NaN       NaN       1.0
# 1       4.0       2.0       2.0       NaN       NaN       2.0
# 2       9.0       9.0       9.0       9.0       9.0       NaN
# 3       1.0       1.0       1.0       NaN       NaN       9.0
# 4       1.0       1.0       1.0       NaN       NaN       1.0
#
# [5 rows x 330 columns]

# %%
data.shape
# Out:
# (441456, 330)

# %%
# Get number of null values
num_of_null_values = data.isnull().sum().sum()
print(num_of_null_values)
# Out:
# 64809261

# %%
# Check how many values are there in the dataset - Minimum 10M values required
num_of_values = data.shape[0] * data.shape[1] - num_of_null_values
print(num_of_values)
# Out:
# 80871219

# %%
# Create a copy of the data dataframe
dataset = data.copy()

# %%
# Check number of values for CVDINFR4 (heart attack column) are the same in the codebook
'''
1 - Yes
2 - No
7 - Don't Know/Not sure
9 - Refused
'''
dataset['CVDINFR4'].value_counts()
# Out:
# 2.0    413755
# 1.0     25472
# 7.0      2038
# 9.0       191
# Name: CVDINFR4, dtype: int64

# %%
# Drop empty columns
dataset.dropna(inplace=True, axis=1, how='all')

# %%
dataset.shape
# Out:
# (441456, 326)

# %%
# Drop columns where all values are the same. This means there is no variation in the data. Check for columns where std = 0. 
std_indices = dataset.std()[(dataset.std() == 0)].index
dataset.drop(std_indices, axis=1, inplace=True)

# %%
dataset.shape
# Out:
# (441456, 321)

# %%
# Drop columns that start with '_' since those are mostly columns derived from other columns
# Keep the following columns: _RACE, _FRUTSUM, _VEGESUM, _BMI5CAT, _PACAT1, _AGEG5YR
for col in dataset.columns:
    if col.startswith('_') and col != "_RACE" and col != "_FRUTSUM" and col != "_VEGESUM" and col != "_BMI5CAT" and col != "_PACAT1" and col != "_AGEG5YR":
        dataset.drop(col, axis=1, inplace = True)

# %%
dataset.shape
# Out:
# (441456, 251)

# %%
# Drop columns with 95% of missing values
dataset = dataset.loc[:, dataset.isnull().sum() < 0.95*dataset.shape[0]]

# %%
dataset.shape
# Out:
# (441456, 186)

# %%
# Check datatype of each column
dataset.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 441456 entries, 0 to 441455
# Data columns (total 186 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   FMONTH    float64
#  1   IDATE     object
#  2   IMONTH    object
#  3   IDAY      object
#  4   IYEAR     object
#  5   DISPCODE  float64
#  6   SEQNO     float64
#  7   PVTRESD1  float64
#  8   CELLFON3  float64
#  9   NUMADULT  float64
#  10  NUMMEN    float64
#  11  NUMWOMEN  float64
#  12  CELLFON2  float64
#  13  CADULT    float64
#  14  PVTRESD2  float64
#  15  CSTATE    float64
#  16  LANDLINE  float64
#  17  HHADULT   float64
#  18  GENHLTH   float64
#  19  PHYSHLTH  float64
#  20  MENTHLTH  float64
#  21  POORHLTH  float64
#  22  HLTHPLN1  float64
#  23  PERSDOC2  float64
#  24  MEDCOST   float64
#  25  CHECKUP1  float64
#  26  BPHIGH4   float64
#  27  BPMEDS    float64
#  28  BLOODCHO  float64
#  29  CHOLCHK   float64
#  30  TOLDHI2   float64
#  31  CVDINFR4  float64
#  32  CVDCRHD4  float64
#  33  CVDSTRK3  float64
#  34  ASTHMA3   float64
#  35  ASTHNOW   float64
#  36  CHCSCNCR  float64
#  37  CHCOCNCR  float64
#  38  CHCCOPD1  float64
#  39  HAVARTH3  float64
#  40  ADDEPEV2  float64
#  41  CHCKIDNY  float64
#  42  DIABETE3  float64
#  43  DIABAGE2  float64
#  44  SEX       float64
#  45  MARITAL   float64
#  46  EDUCA     float64
#  47  RENTHOM1  float64
#  48  NUMHHOL2  float64
#  49  CPDEMO1   float64
#  50  VETERAN3  float64
#  51  EMPLOY1   float64
#  52  CHILDREN  float64
#  53  INCOME2   float64
#  54  INTERNET  float64
#  55  WEIGHT2   float64
#  56  HEIGHT3   float64
#  57  PREGNANT  float64
#  58  QLACTLM2  float64
#  59  USEEQUIP  float64
#  60  BLIND     float64
#  61  DECIDE    float64
#  62  DIFFWALK  float64
#  63  DIFFDRES  float64
#  64  DIFFALON  float64
#  65  SMOKE100  float64
#  66  SMOKDAY2  float64
#  67  STOPSMK2  float64
#  68  LASTSMK2  float64
#  69  USENOW3   float64
#  70  ALCDAY5   float64
#  71  AVEDRNK2  float64
#  72  DRNK3GE5  float64
#  73  MAXDRNKS  float64
#  74  FRUITJU1  float64
#  75  FRUIT1    float64
#  76  FVBEANS   float64
#  77  FVGREEN   float64
#  78  FVORANG   float64
#  79  VEGETAB1  float64
#  80  EXERANY2  float64
#  81  EXRACT11  float64
#  82  EXEROFT1  float64
#  83  EXERHMM1  float64
#  84  EXRACT21  float64
#  85  EXEROFT2  float64
#  86  EXERHMM2  float64
#  87  STRENGTH  float64
#  88  LMTJOIN3  float64
#  89  ARTHDIS2  float64
#  90  ARTHSOCL  float64
#  91  JOINPAIN  float64
#  92  SEATBELT  float64
#  93  FLUSHOT6  float64
#  94  FLSHTMY2  float64
#  95  IMFVPLAC  float64
#  96  PNEUVAC3  float64
#  97  HIVTST6   float64
#  98  HIVTSTD3  float64
#  99  WHRTST10  float64
#  100 PDIABTST  float64
#  101 PREDIAB1  float64
#  102 INSULIN   float64
#  103 BLDSUGAR  float64
#  104 FEETCHK2  float64
#  105 DOCTDIAB  float64
#  106 CHKHEMO3  float64
#  107 FEETCHK   float64
#  108 EYEEXAM   float64
#  109 DIABEYE   float64
#  110 DIABEDU   float64
#  111 CAREGIV1  float64
#  112 CRGVREL1  float64
#  113 CRGVLNG1  float64
#  114 CRGVHRS1  float64
#  115 CRGVPRB1  float64
#  116 CRGVPERS  float64
#  117 CRGVHOUS  float64
#  118 CRGVMST2  float64
#  119 CRGVEXPT  float64
#  120 CIMEMLOS  float64
#  121 WTCHSALT  float64
#  122 LONGWTCH  float64
#  123 DRADVISE  float64
#  124 TETANUS   float64
#  125 SHINGLE2  float64
#  126 HADMAM    float64
#  127 HADPAP2   float64
#  128 HPVTEST   float64
#  129 HADHYST2  float64
#  130 BLDSTOOL  float64
#  131 HADSIGM3  float64
#  132 HADSGCO1  float64
#  133 LASTSIG3  float64
#  134 PCDMDECN  object
#  135 SCNTMNY1  float64
#  136 SCNTMEL1  float64
#  137 SCNTPAID  float64
#  138 SCNTWRK1  float64
#  139 SCNTLPAD  float64
#  140 SCNTLWK1  float64
#  141 SXORIENT  float64
#  142 TRNSGNDR  float64
#  143 RCSGENDR  float64
#  144 RCSRLTN2  float64
#  145 CASTHDX2  float64
#  146 QSTVER    float64
#  147 QSTLANG   float64
#  148 EXACTOT1  object
#  149 EXACTOT2  object
#  150 MSCODE    float64
#  151 _RACE     float64
#  152 _AGEG5YR  float64
#  153 HTIN4     float64
#  154 HTM4      float64
#  155 WTKG3     float64
#  156 _BMI5CAT  float64
#  157 DRNKANY5  float64
#  158 DROCDY3_  float64
#  159 FTJUDA1_  float64
#  160 FRUTDA1_  float64
#  161 BEANDAY_  float64
#  162 GRENDAY_  float64
#  163 ORNGDAY_  float64
#  164 VEGEDA1_  float64
#  165 _FRUTSUM  float64
#  166 _VEGESUM  float64
#  167 METVL11_  float64
#  168 METVL21_  float64
#  169 MAXVO2_   float64
#  170 FC60_     float64
#  171 ACTIN11_  float64
#  172 ACTIN21_  float64
#  173 PADUR1_   float64
#  174 PADUR2_   float64
#  175 PAFREQ1_  float64
#  176 PAFREQ2_  float64
#  177 STRFREQ_  float64
#  178 PAMISS1_  float64
#  179 PAMIN11_  float64
#  180 PAMIN21_  float64
#  181 PA1MIN_   float64
#  182 PAVIG11_  float64
#  183 PAVIG21_  float64
#  184 PA1VIGM_  float64
#  185 _PACAT1   float64
# dtypes: float64(179), object(7)
# memory usage: 626.5+ MB

# %%
# Check how many values are empty in EXACTOT1 column. 
dataset[dataset['EXACTOT1'] == "b''"].EXACTOT1.count()
# Out:
# 428378

# %%
# Check how many values are empty in EXACTOT2 column.
dataset[dataset['EXACTOT2'] == "b''"].EXACTOT2.count()
# Out:
# 424831

# %%
# Check how many values are empty in PCDMDECN column. 
dataset[dataset['PCDMDECN'] == "b''"].PCDMDECN.count()
# Out:
# 441201

# %%
# Keep columns with datatype float64 to keep columns with categorical values only. 
# Columns IDATE, IMONTH, IDAY, and IYEAR can be drop as they represent the interview date which is irrelevant for predictions
dataset = dataset.select_dtypes(include=['float64'])

# %%
# Check columns have datatype float64 only.
dataset.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 441456 entries, 0 to 441455
# Data columns (total 179 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   FMONTH    float64
#  1   DISPCODE  float64
#  2   SEQNO     float64
#  3   PVTRESD1  float64
#  4   CELLFON3  float64
#  5   NUMADULT  float64
#  6   NUMMEN    float64
#  7   NUMWOMEN  float64
#  8   CELLFON2  float64
#  9   CADULT    float64
#  10  PVTRESD2  float64
#  11  CSTATE    float64
#  12  LANDLINE  float64
#  13  HHADULT   float64
#  14  GENHLTH   float64
#  15  PHYSHLTH  float64
#  16  MENTHLTH  float64
#  17  POORHLTH  float64
#  18  HLTHPLN1  float64
#  19  PERSDOC2  float64
#  20  MEDCOST   float64
#  21  CHECKUP1  float64
#  22  BPHIGH4   float64
#  23  BPMEDS    float64
#  24  BLOODCHO  float64
#  25  CHOLCHK   float64
#  26  TOLDHI2   float64
#  27  CVDINFR4  float64
#  28  CVDCRHD4  float64
#  29  CVDSTRK3  float64
#  30  ASTHMA3   float64
#  31  ASTHNOW   float64
#  32  CHCSCNCR  float64
#  33  CHCOCNCR  float64
#  34  CHCCOPD1  float64
#  35  HAVARTH3  float64
#  36  ADDEPEV2  float64
#  37  CHCKIDNY  float64
#  38  DIABETE3  float64
#  39  DIABAGE2  float64
#  40  SEX       float64
#  41  MARITAL   float64
#  42  EDUCA     float64
#  43  RENTHOM1  float64
#  44  NUMHHOL2  float64
#  45  CPDEMO1   float64
#  46  VETERAN3  float64
#  47  EMPLOY1   float64
#  48  CHILDREN  float64
#  49  INCOME2   float64
#  50  INTERNET  float64
#  51  WEIGHT2   float64
#  52  HEIGHT3   float64
#  53  PREGNANT  float64
#  54  QLACTLM2  float64
#  55  USEEQUIP  float64
#  56  BLIND     float64
#  57  DECIDE    float64
#  58  DIFFWALK  float64
#  59  DIFFDRES  float64
#  60  DIFFALON  float64
#  61  SMOKE100  float64
#  62  SMOKDAY2  float64
#  63  STOPSMK2  float64
#  64  LASTSMK2  float64
#  65  USENOW3   float64
#  66  ALCDAY5   float64
#  67  AVEDRNK2  float64
#  68  DRNK3GE5  float64
#  69  MAXDRNKS  float64
#  70  FRUITJU1  float64
#  71  FRUIT1    float64
#  72  FVBEANS   float64
#  73  FVGREEN   float64
#  74  FVORANG   float64
#  75  VEGETAB1  float64
#  76  EXERANY2  float64
#  77  EXRACT11  float64
#  78  EXEROFT1  float64
#  79  EXERHMM1  float64
#  80  EXRACT21  float64
#  81  EXEROFT2  float64
#  82  EXERHMM2  float64
#  83  STRENGTH  float64
#  84  LMTJOIN3  float64
#  85  ARTHDIS2  float64
#  86  ARTHSOCL  float64
#  87  JOINPAIN  float64
#  88  SEATBELT  float64
#  89  FLUSHOT6  float64
#  90  FLSHTMY2  float64
#  91  IMFVPLAC  float64
#  92  PNEUVAC3  float64
#  93  HIVTST6   float64
#  94  HIVTSTD3  float64
#  95  WHRTST10  float64
#  96  PDIABTST  float64
#  97  PREDIAB1  float64
#  98  INSULIN   float64
#  99  BLDSUGAR  float64
#  100 FEETCHK2  float64
#  101 DOCTDIAB  float64
#  102 CHKHEMO3  float64
#  103 FEETCHK   float64
#  104 EYEEXAM   float64
#  105 DIABEYE   float64
#  106 DIABEDU   float64
#  107 CAREGIV1  float64
#  108 CRGVREL1  float64
#  109 CRGVLNG1  float64
#  110 CRGVHRS1  float64
#  111 CRGVPRB1  float64
#  112 CRGVPERS  float64
#  113 CRGVHOUS  float64
#  114 CRGVMST2  float64
#  115 CRGVEXPT  float64
#  116 CIMEMLOS  float64
#  117 WTCHSALT  float64
#  118 LONGWTCH  float64
#  119 DRADVISE  float64
#  120 TETANUS   float64
#  121 SHINGLE2  float64
#  122 HADMAM    float64
#  123 HADPAP2   float64
#  124 HPVTEST   float64
#  125 HADHYST2  float64
#  126 BLDSTOOL  float64
#  127 HADSIGM3  float64
#  128 HADSGCO1  float64
#  129 LASTSIG3  float64
#  130 SCNTMNY1  float64
#  131 SCNTMEL1  float64
#  132 SCNTPAID  float64
#  133 SCNTWRK1  float64
#  134 SCNTLPAD  float64
#  135 SCNTLWK1  float64
#  136 SXORIENT  float64
#  137 TRNSGNDR  float64
#  138 RCSGENDR  float64
#  139 RCSRLTN2  float64
#  140 CASTHDX2  float64
#  141 QSTVER    float64
#  142 QSTLANG   float64
#  143 MSCODE    float64
#  144 _RACE     float64
#  145 _AGEG5YR  float64
#  146 HTIN4     float64
#  147 HTM4      float64
#  148 WTKG3     float64
#  149 _BMI5CAT  float64
#  150 DRNKANY5  float64
#  151 DROCDY3_  float64
#  152 FTJUDA1_  float64
#  153 FRUTDA1_  float64
#  154 BEANDAY_  float64
#  155 GRENDAY_  float64
#  156 ORNGDAY_  float64
#  157 VEGEDA1_  float64
#  158 _FRUTSUM  float64
#  159 _VEGESUM  float64
#  160 METVL11_  float64
#  161 METVL21_  float64
#  162 MAXVO2_   float64
#  163 FC60_     float64
#  164 ACTIN11_  float64
#  165 ACTIN21_  float64
#  166 PADUR1_   float64
#  167 PADUR2_   float64
#  168 PAFREQ1_  float64
#  169 PAFREQ2_  float64
#  170 STRFREQ_  float64
#  171 PAMISS1_  float64
#  172 PAMIN11_  float64
#  173 PAMIN21_  float64
#  174 PA1MIN_   float64
#  175 PAVIG11_  float64
#  176 PAVIG21_  float64
#  177 PA1VIGM_  float64
#  178 _PACAT1   float64
# dtypes: float64(179)
# memory usage: 602.9 MB

# %%
dataset.shape
# Out:
# (441456, 179)

# %%
# Get rows where CVDINFR4 = 1 or 2 from the dataset. Ignore rows where CVDINFR4 = 7 or 9.
dataset = dataset.loc[dataset['CVDINFR4'].isin([1, 2])]
dataset.reset_index(drop=True, inplace=True)

# %%
dataset['CVDINFR4']
# Out:
# 0         2.0
# 1         2.0
# 2         2.0
# 3         2.0
# 4         2.0
#          ...
# 439222    2.0
# 439223    2.0
# 439224    2.0
# 439225    2.0
# 439226    1.0
# Name: CVDINFR4, Length: 439227, dtype: float64

# %%
# Get labels from the dataset
labels = dataset[['CVDINFR4']].astype(int)

# %%
labels
# Out:
#         CVDINFR4
# 0              2
# 1              2
# 2              2
# 3              2
# 4              2
# ...          ...
# 439222         2
# 439223         2
# 439224         2
# 439225         2
# 439226         1
#
# [439227 rows x 1 columns]

# %%
# Change labels to 0 - No heart attack and 1 - heart attack. Values with 1 stay the same. Change '2' values to '0'
labels['CVDINFR4'].replace(2, 0, inplace=True)

# %%
labels
# Out:
#         CVDINFR4
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 439222         0
# 439223         0
# 439224         0
# 439225         0
# 439226         1
#
# [439227 rows x 1 columns]

# %%
# Remove the labels (CVDINFR4 column) from the dataset
dataset.drop(['CVDINFR4'], axis=1, inplace=True)

# %%
dataset.shape
# Out:
# (439227, 178)

# %%
# Check correlation of columns using a correlation matrix. For this fill in NA values first.
# Followed the code in this page: https://chrisalbon.com/machine_learning/feature_selection/drop_highly_correlated_features/
dataset2 = dataset.fillna(-1)
correlation_matrix = dataset2.corr().abs()

# %%
correlation_matrix
# Out:
#             FMONTH  DISPCODE     SEQNO  PVTRESD1  CELLFON3  NUMADULT  \
# FMONTH    1.000000  0.005900  0.248180  0.009287  0.007349  0.006565
# DISPCODE  0.005900  1.000000  0.053581  0.141937  0.139455  0.128497
# SEQNO     0.248180  0.053581  1.000000  0.577408  0.561521  0.529077
# PVTRESD1  0.009287  0.141937  0.577408  1.000000  0.957589  0.915411
# CELLFON3  0.007349  0.139455  0.561521  0.957589  1.000000  0.876805
# ...            ...       ...       ...       ...       ...       ...
# PA1MIN_   0.026305  0.118678  0.015470  0.035428  0.030323  0.028866
# PAVIG11_  0.019205  0.077802  0.037989  0.071841  0.065982  0.052011
# PAVIG21_  0.017343  0.061844  0.026710  0.054345  0.050852  0.040238
# PA1VIGM_  0.024217  0.092725  0.043540  0.084563  0.078222  0.061723
# _PACAT1   0.010844  0.539209  0.019998  0.023141  0.022645  0.029225
#
#             NUMMEN  NUMWOMEN  CELLFON2    CADULT  ...  PAFREQ2_  STRFREQ_  \
# FMONTH    0.005249  0.008961  0.009304  0.009132  ...  0.010122  0.009287
# DISPCODE  0.124509  0.130212  0.141970  0.134712  ...  0.120111  0.104059
# SEQNO     0.510644  0.534488  0.577448  0.557141  ...  0.003498  0.018010
# PVTRESD1  0.883331  0.926192  0.999946  0.967078  ...  0.013308  0.036003
# CELLFON3  0.846202  0.887446  0.957650  0.926173  ...  0.012086  0.038112
# ...            ...       ...       ...       ...  ...       ...       ...
# PA1MIN_   0.035245  0.023895  0.035450  0.038762  ...  0.419968  0.126556
# PAVIG11_  0.055973  0.053975  0.071856  0.070802  ...  0.147447  0.066329
# PAVIG21_  0.041529  0.042807  0.054366  0.052981  ...  0.294320  0.050789
# PA1VIGM_  0.065371  0.064696  0.084586  0.082998  ...  0.279677  0.077962
# _PACAT1   0.033568  0.020306  0.023165  0.023036  ...  0.324292  0.202427
#
#           PAMISS1_  PAMIN11_  PAMIN21_   PA1MIN_  PAVIG11_  PAVIG21_  \
# FMONTH    0.005422  0.023855  0.016107  0.026305  0.019205  0.017343
# DISPCODE  0.712436  0.106318  0.074454  0.118678  0.077802  0.061844
# SEQNO     0.041829  0.012906  0.010715  0.015470  0.037989  0.026710
# PVTRESD1  0.045033  0.028431  0.025837  0.035428  0.071841  0.054345
# CELLFON3  0.046359  0.022974  0.023650  0.030323  0.065982  0.050852
# ...            ...       ...       ...       ...       ...       ...
# PA1MIN_   0.155062  0.800362  0.733061  1.000000  0.642443  0.567011
# PAVIG11_  0.087364  0.811041  0.134088  0.642443  1.000000  0.139947
# PAVIG21_  0.068445  0.151378  0.758758  0.567011  0.139947  1.000000
# PA1VIGM_  0.103383  0.683262  0.541704  0.802483  0.815504  0.687180
# _PACAT1   0.749822  0.358331  0.251700  0.400646  0.237882  0.185891
#
#           PA1VIGM_   _PACAT1
# FMONTH    0.024217  0.010844
# DISPCODE  0.092725  0.539209
# SEQNO     0.043540  0.019998
# PVTRESD1  0.084563  0.023141
# CELLFON3  0.078222  0.022645
# ...            ...       ...
# PA1MIN_   0.802483  0.400646
# PAVIG11_  0.815504  0.237882
# PAVIG21_  0.687180  0.185891
# PA1VIGM_  1.000000  0.282035
# _PACAT1   0.282035  1.000000
#
# [178 rows x 178 columns]

# %%
plt.matshow(dataset2.corr())
plt.show()

# %%
# Get correlations from the upper triangle in the correlation matrix
utriangle = correlation_matrix.where(np.triu(np.ones(correlation_matrix.shape), k=1).astype(np.bool))

# %%
utriangle
# Out:
#           FMONTH  DISPCODE     SEQNO  PVTRESD1  CELLFON3  NUMADULT    NUMMEN  \
# FMONTH       NaN    0.0059  0.248180  0.009287  0.007349  0.006565  0.005249
# DISPCODE     NaN       NaN  0.053581  0.141937  0.139455  0.128497  0.124509
# SEQNO        NaN       NaN       NaN  0.577408  0.561521  0.529077  0.510644
# PVTRESD1     NaN       NaN       NaN       NaN  0.957589  0.915411  0.883331
# CELLFON3     NaN       NaN       NaN       NaN       NaN  0.876805  0.846202
# ...          ...       ...       ...       ...       ...       ...       ...
# PA1MIN_      NaN       NaN       NaN       NaN       NaN       NaN       NaN
# PAVIG11_     NaN       NaN       NaN       NaN       NaN       NaN       NaN
# PAVIG21_     NaN       NaN       NaN       NaN       NaN       NaN       NaN
# PA1VIGM_     NaN       NaN       NaN       NaN       NaN       NaN       NaN
# _PACAT1      NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#           NUMWOMEN  CELLFON2    CADULT  ...  PAFREQ2_  STRFREQ_  PAMISS1_  \
# FMONTH    0.008961  0.009304  0.009132  ...  0.010122  0.009287  0.005422
# DISPCODE  0.130212  0.141970  0.134712  ...  0.120111  0.104059  0.712436
# SEQNO     0.534488  0.577448  0.557141  ...  0.003498  0.018010  0.041829
# PVTRESD1  0.926192  0.999946  0.967078  ...  0.013308  0.036003  0.045033
# CELLFON3  0.887446  0.957650  0.926173  ...  0.012086  0.038112  0.046359
# ...            ...       ...       ...  ...       ...       ...       ...
# PA1MIN_        NaN       NaN       NaN  ...       NaN       NaN       NaN
# PAVIG11_       NaN       NaN       NaN  ...       NaN       NaN       NaN
# PAVIG21_       NaN       NaN       NaN  ...       NaN       NaN       NaN
# PA1VIGM_       NaN       NaN       NaN  ...       NaN       NaN       NaN
# _PACAT1        NaN       NaN       NaN  ...       NaN       NaN       NaN
#
#           PAMIN11_  PAMIN21_   PA1MIN_  PAVIG11_  PAVIG21_  PA1VIGM_   _PACAT1
# FMONTH    0.023855  0.016107  0.026305  0.019205  0.017343  0.024217  0.010844
# DISPCODE  0.106318  0.074454  0.118678  0.077802  0.061844  0.092725  0.539209
# SEQNO     0.012906  0.010715  0.015470  0.037989  0.026710  0.043540  0.019998
# PVTRESD1  0.028431  0.025837  0.035428  0.071841  0.054345  0.084563  0.023141
# CELLFON3  0.022974  0.023650  0.030323  0.065982  0.050852  0.078222  0.022645
# ...            ...       ...       ...       ...       ...       ...       ...
# PA1MIN_        NaN       NaN       NaN  0.642443  0.567011  0.802483  0.400646
# PAVIG11_       NaN       NaN       NaN       NaN  0.139947  0.815504  0.237882
# PAVIG21_       NaN       NaN       NaN       NaN       NaN  0.687180  0.185891
# PA1VIGM_       NaN       NaN       NaN       NaN       NaN       NaN  0.282035
# _PACAT1        NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
# [178 rows x 178 columns]

# %%
# Find columns with correlation greater than 0.90
high_correlated_columns = [col for col in utriangle.columns if any (utriangle[col] > 0.90)]

# %%
high_correlated_columns
# Out:
# ['CELLFON3',
#  'NUMADULT',
#  'NUMMEN',
#  'NUMWOMEN',
#  'CELLFON2',
#  'CADULT',
#  'PVTRESD2',
#  'CSTATE',
#  'LANDLINE',
#  'BPMEDS',
#  'NUMHHOL2',
#  'CPDEMO1',
#  'ARTHSOCL',
#  'EYEEXAM',
#  'DIABEYE',
#  'DIABEDU',
#  'CRGVHOUS',
#  'CRGVMST2',
#  'DRADVISE',
#  'HADPAP2',
#  'HADHYST2',
#  'HADSIGM3',
#  'LASTSIG3',
#  'SCNTMEL1',
#  'QSTVER',
#  'HTM4',
#  'DROCDY3_',
#  'FC60_']

# %%
# Drop high correlated columns from the dataset
dataset.drop(high_correlated_columns, axis=1, inplace=True)

# %%
for col in dataset.columns:
    print(col)
# Out:
# FMONTH
# DISPCODE
# SEQNO
# PVTRESD1
# HHADULT
# GENHLTH
# PHYSHLTH
# MENTHLTH
# POORHLTH
# HLTHPLN1
# PERSDOC2
# MEDCOST
# CHECKUP1
# BPHIGH4
# BLOODCHO
# CHOLCHK
# TOLDHI2
# CVDCRHD4
# CVDSTRK3
# ASTHMA3
# ASTHNOW
# CHCSCNCR
# CHCOCNCR
# CHCCOPD1
# HAVARTH3
# ADDEPEV2
# CHCKIDNY
# DIABETE3
# DIABAGE2
# SEX
# MARITAL
# EDUCA
# RENTHOM1
# VETERAN3
# EMPLOY1
# CHILDREN
# INCOME2
# INTERNET
# WEIGHT2
# HEIGHT3
# PREGNANT
# QLACTLM2
# USEEQUIP
# BLIND
# DECIDE
# DIFFWALK
# DIFFDRES
# DIFFALON
# SMOKE100
# SMOKDAY2
# STOPSMK2
# LASTSMK2
# USENOW3
# ALCDAY5
# AVEDRNK2
# DRNK3GE5
# MAXDRNKS
# FRUITJU1
# FRUIT1
# FVBEANS
# FVGREEN
# FVORANG
# VEGETAB1
# EXERANY2
# EXRACT11
# EXEROFT1
# EXERHMM1
# EXRACT21
# EXEROFT2
# EXERHMM2
# STRENGTH
# LMTJOIN3
# ARTHDIS2
# JOINPAIN
# SEATBELT
# FLUSHOT6
# FLSHTMY2
# IMFVPLAC
# PNEUVAC3
# HIVTST6
# HIVTSTD3
# WHRTST10
# PDIABTST
# PREDIAB1
# INSULIN
# BLDSUGAR
# FEETCHK2
# DOCTDIAB
# CHKHEMO3
# FEETCHK
# CAREGIV1
# CRGVREL1
# CRGVLNG1
# CRGVHRS1
# CRGVPRB1
# CRGVPERS
# CRGVEXPT
# CIMEMLOS
# WTCHSALT
# LONGWTCH
# TETANUS
# SHINGLE2
# HADMAM
# HPVTEST
# BLDSTOOL
# HADSGCO1
# SCNTMNY1
# SCNTPAID
# SCNTWRK1
# SCNTLPAD
# SCNTLWK1
# SXORIENT
# TRNSGNDR
# RCSGENDR
# RCSRLTN2
# CASTHDX2
# QSTLANG
# MSCODE
# _RACE
# _AGEG5YR
# HTIN4
# WTKG3
# _BMI5CAT
# DRNKANY5
# FTJUDA1_
# FRUTDA1_
# BEANDAY_
# GRENDAY_
# ORNGDAY_
# VEGEDA1_
# _FRUTSUM
# _VEGESUM
# METVL11_
# METVL21_
# MAXVO2_
# ACTIN11_
# ACTIN21_
# PADUR1_
# PADUR2_
# PAFREQ1_
# PAFREQ2_
# STRFREQ_
# PAMISS1_
# PAMIN11_
# PAMIN21_
# PA1MIN_
# PAVIG11_
# PAVIG21_
# PA1VIGM_
# _PACAT1

# %%
# Drop other columns not related to health manually
dataset.drop(columns = ['FMONTH','DISPCODE','SEQNO','PVTRESD1','HHADULT'], axis=1, inplace = True)

# %%
dataset.shape
# Out:
# (439227, 145)

# %%
# Normalize dataset
scaler = StandardScaler()
dataset_norm = scaler.fit_transform(dataset)

# %%
dataset_norm
# Out:
# array([[ 2.17532449, -1.23331316, -1.30286436, ...,         nan,
#                 nan,  0.30328738],
#        [ 0.38154116,  0.73675761,  0.65013274, ..., -0.2682094 ,
#         -0.41586533, -0.50782117],
#        [ 2.17532449, -0.8285041 , -0.96806486, ...,         nan,
#                 nan,  0.30328738],
#        ...,
#        [ 1.27843282,  0.73675761, -1.24706444, ...,         nan,
#                 nan,  2.33105877],
#        [ 0.38154116,  0.73675761,  0.65013274, ...,         nan,
#                 nan,  0.30328738],
#        [-0.51535051,  0.73675761,  0.65013274, ..., -0.2682094 ,
#         -0.41586533, -0.10226689]])

# %%
# Get feature importance using XGBClassifier from XGBoost
# Followed the code in this page: https://machinelearningmastery.com/feature-importance-and-feature-selection-with-xgboost-in-python/

# Divide data in training and test
X_train, X_test, y_train, y_test = train_test_split(dataset_norm, labels, shuffle=True, test_size=0.2, random_state=42)
X_train_df = pd.DataFrame(data = X_train, columns=dataset.columns)
X_train_df.head()
# Out:
#     GENHLTH  PHYSHLTH  MENTHLTH  POORHLTH  HLTHPLN1  PERSDOC2   MEDCOST  \
# 0 -0.515351 -1.584148  0.650133  0.845488 -0.197973 -0.474695  0.204616
# 1  0.381541  0.736758  0.650133       NaN -0.197973 -0.474695  0.204616
# 2 -0.515351  0.736758 -1.749264 -1.150390 -0.197973 -0.474695  0.204616
# 3  0.381541 -1.530173 -1.526064 -1.202914 -0.197973 -0.474695 -2.230236
# 4  0.381541  0.736758  0.650133       NaN -0.197973  0.728851  0.204616
#
#    CHECKUP1   BPHIGH4  BLOODCHO  ...  PAFREQ2_  STRFREQ_  PAMISS1_  PAMIN11_  \
# 0 -0.459962 -1.170248 -0.264305  ...       NaN       NaN  0.071890 -0.255574
# 1 -0.459962 -1.170248 -0.264305  ... -0.041870  0.354003 -0.325957  4.215158
# 2 -0.459962 -1.170248 -0.264305  ... -0.669446 -0.532143 -0.325957 -0.398867
# 3 -0.459962 -1.170248 -0.264305  ...       NaN -0.532143 -0.325957       NaN
# 4 -0.459962  0.763487  0.832724  ...       NaN       NaN  3.254665       NaN
#
#    PAMIN21_   PA1MIN_  PAVIG11_  PAVIG21_  PA1VIGM_   _PACAT1
# 0       NaN -0.408596  0.032425       NaN -0.130901  2.331059
# 1  2.622902  4.676152 -0.351060  3.522167  1.863847 -0.913375
# 2 -0.253683 -0.428774 -0.351060 -0.268209 -0.415865 -0.507821
# 3       NaN       NaN       NaN       NaN       NaN  0.303287
# 4       NaN       NaN       NaN       NaN       NaN  2.331059
#
# [5 rows x 145 columns]

# %%
# Fit model
model = XGBClassifier(use_label_encoder=False)
model.fit(X_train_df, y_train)
# Out:
# [15:00:24] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=100, n_jobs=24, num_parallel_tree=1, random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', use_label_encoder=False,
#               validate_parameters=1, verbosity=None)

# %%
# Plot feature importance
ax = plot_importance(model, height=0.5, importance_type="gain")

fig = ax.figure
fig.set_size_inches(10, 50)

# %%
y_true, y_pred = y_test, model.predict(X_test)
print(classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97     82801
#            1       0.60      0.30      0.40      5045
#
#     accuracy                           0.95     87846
#    macro avg       0.78      0.65      0.69     87846
# weighted avg       0.94      0.95      0.94     87846

# %%
# Need to reduce the number of False Negatives (FN) when 1 is Positive in order to increase the recall score 
# and have more True Positive (TP) values because I am interested in predicting when a person CAN have a Heart attack.

# %%
# Accuracy is high because most '0's (not heart attack) are being predicted correctly. This occurs because only 5045 rows are 
# predicting '1's (heart attack) while a lot more rows 82801 are predicting '0's (not heart attack) meaning the data is
# skewed/imbalanced.

# %%
# Trying to fix the imbalanced classification
# Followed the code from this page: https://machinelearningmastery.com/xgboost-for-imbalanced-classification/

# Estimate scale_pos_weight value
counter = Counter(y_pred)
estimate = counter[0] / counter[1]
print('Estimate: %.3f' % estimate)
# Out:
# Estimate: 33.181

# %%
model = XGBClassifier(use_label_encoder=False, scale_pos_weight=33)
model.fit(X_train_df, y_train)
# Out:
# [15:01:03] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=100, n_jobs=24, num_parallel_tree=1, random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=33, subsample=1,
#               tree_method='exact', use_label_encoder=False,
#               validate_parameters=1, verbosity=None)

# %%
# Plot feature importance
ax = plot_importance(model, height=0.5, importance_type="gain")

fig = ax.figure
fig.set_size_inches(10, 50)

# %%
y_true, y_pred = y_test, model.predict(X_test)
print(classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.76      0.86     82801
#            1       0.18      0.84      0.29      5045
#
#     accuracy                           0.76     87846
#    macro avg       0.58      0.80      0.57     87846
# weighted avg       0.94      0.76      0.83     87846

# %%
# Even though accuracy is lower after setting the class imbalance hyperparameter, the recall values are significantly higher.
# In this case having higher recall values is important to make sure samples with susceptibility of Heart Attack are
# classified correctly.

# %%
# Take only first 50 important features and check recall
sorted_indices = model.feature_importances_.argsort()
imp_features = dataset.columns[sorted_indices][-50:]

# %%
imp_features
# Out:
# Index(['FRUTDA1_', 'HTIN4', 'PDIABTST', 'PAFREQ2_', 'LASTSMK2', 'TRNSGNDR',
#        'PREDIAB1', 'HAVARTH3', 'ACTIN11_', 'BLOODCHO', 'MARITAL', 'CASTHDX2',
#        'DIABETE3', 'MAXDRNKS', 'BLIND', 'HADSGCO1', 'DRNK3GE5', 'HADMAM',
#        'JOINPAIN', 'USENOW3', 'INCOME2', 'VETERAN3', 'PAMISS1_', 'PREGNANT',
#        'AVEDRNK2', 'CHCKIDNY', 'USEEQUIP', 'MEDCOST', 'ADDEPEV2', '_PACAT1',
#        'EDUCA', 'QLACTLM2', 'DIABAGE2', 'PNEUVAC3', 'SMOKDAY2', 'CHOLCHK',
#        'SMOKE100', 'STOPSMK2', 'TOLDHI2', 'MAXVO2_', 'CHCCOPD1', 'INTERNET',
#        'SEX', 'CVDSTRK3', 'GENHLTH', 'DIFFWALK', '_AGEG5YR', 'BPHIGH4',
#        'EMPLOY1', 'CVDCRHD4'],
#       dtype='object')

# %%
imp_features_dataset = dataset[imp_features]

# %%
imp_features_dataset.head()
# Out:
#    FRUTDA1_  HTIN4  PDIABTST  PAFREQ2_  LASTSMK2  TRNSGNDR  PREDIAB1  \
# 0      33.0   70.0       1.0       NaN       2.0       NaN       3.0
# 1      17.0   68.0       2.0    2800.0       NaN       NaN       3.0
# 2     100.0   67.0       2.0       NaN       NaN       NaN       3.0
# 3     200.0   64.0       1.0       NaN       NaN       NaN       3.0
# 4     100.0   62.0       1.0    7000.0       NaN       NaN       3.0
#
#    HAVARTH3  ACTIN11_  BLOODCHO  ...  CHCCOPD1  INTERNET  SEX  CVDSTRK3  \
# 0       1.0       NaN       1.0  ...       1.0       2.0  2.0       2.0
# 1       2.0       1.0       1.0  ...       2.0       1.0  2.0       2.0
# 2       1.0       NaN       1.0  ...       2.0       2.0  2.0       2.0
# 3       1.0       NaN       1.0  ...       2.0       1.0  2.0       2.0
# 4       1.0       2.0       1.0  ...       2.0       2.0  2.0       2.0
#
#    GENHLTH  DIFFWALK  _AGEG5YR  BPHIGH4  EMPLOY1  CVDCRHD4
# 0      5.0       1.0       9.0      1.0      8.0       2.0
# 1      3.0       2.0       7.0      3.0      3.0       2.0
# 2      5.0       1.0       9.0      1.0      8.0       2.0
# 3      5.0       2.0       9.0      3.0      8.0       2.0
# 4      2.0       2.0      11.0      1.0      2.0       2.0
#
# [5 rows x 50 columns]

# %%
# Normalize dataset
scaler = StandardScaler()
imp_features_dataset_norm = scaler.fit_transform(imp_features_dataset)

# %%
# Divide data in training and test
X_train, X_test, y_train, y_test = train_test_split(imp_features_dataset_norm, labels, shuffle=True, test_size=0.2, random_state=42)

# %%
# Important feature model training and prediction
model1 = XGBClassifier(use_label_encoder=False, scale_pos_weight=33)
model1.fit(X_train, y_train)
y_true, y_pred = y_test, model1.predict(X_test)
print(classification_report(y_true, y_pred))
# Out:
# [15:01:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#               precision    recall  f1-score   support
#
#            0       0.99      0.74      0.85     82801
#            1       0.17      0.86      0.28      5045
#
#     accuracy                           0.75     87846
#    macro avg       0.58      0.80      0.56     87846
# weighted avg       0.94      0.75      0.81     87846

# %%
# Check current dataset shape
imp_features_dataset.shape
# Out:
# (439227, 50)

# %%
# Insert back the labels to the dataset
imp_features_dataset.insert(len(imp_features_dataset.columns), 'CVDINFR4', labels)

# %%
# Check dataset shape after labels insertion
imp_features_dataset.shape
# Out:
# (439227, 51)

# %%
imp_features_dataset.to_csv('preprocessed_dataset.csv', index=False)
